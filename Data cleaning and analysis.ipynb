# %%
import pickle, re
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from yellowbrick.text import FreqDistVisualizer
import matplotlib as plt
import spacy

# %% [markdown]
# # Get the data and check it

# %%
unpickled_df = pd.read_pickle("C:/Users/amt/Documents/0. MSc Tinbergen/block 5. NLP/extracted_data.pkl")

# %%
#unpickled_df

# %% [markdown]
# * Take out the nan values

# %%
df = unpickled_df[unpickled_df['description'].notna()]
#df

# %% [markdown]
# # Corpus warm-up:
# * Create the corpus of abstracts

# %%
corpus = df["description"].tolist()

# %%
#check how some values look like
#corpus[0], corpus[1010], corpus[2]

# %%
#type(corpus[0])

# %%
#len(corpus)
#1028 abstracts

# %%
#to count the amount of words in the entire dataset, also repeating
corpus_all = []

for i in range(0,len(corpus)):
    res = re.findall(r'\w+', corpus[i])
    corpus_all.extend(res)
    
#corpus_all

# %%
#len(corpus_all)

# %%
#type(corpus_all)

# %%
#print(corpus_all)

# %% [markdown]
# * Create a list all the unique words in the corpus

# %%
lister = []
for i in corpus_all:
    if i not in lister:
        lister.append(i)
            
#print(lister)
print("There are", len(lister), "unique words in that list")
# Out:
# There are 14297 unique words in that list

# %% [markdown]
# * Tokenize and check the words most frequent in the entire corpus

# %%
vectorizer = CountVectorizer()
docs       = vectorizer.fit_transform(corpus)
features   = vectorizer.get_feature_names()

visualizer = FreqDistVisualizer(features=features, n=75, size= (520, 860))
visualizer.fit(docs)
visualizer.show()

# %% [markdown]
# ### Take out english stopwords and check which are the most used words

# %%
vectorizer = CountVectorizer(stop_words='english')
docs       = vectorizer.fit_transform(corpus)
features   = vectorizer.get_feature_names()

visualizer = FreqDistVisualizer(features=features, n=75,  size= (520, 860))
visualizer.fit(docs)
visualizer.show()

# %%
from sklearn.feature_extraction import stop_words
print(stop_words.ENGLISH_STOP_WORDS)
# Out:
# frozenset({'too', 'upon', 'anyone', 'everyone', 'meanwhile', 'i', 'myself', 'very', 'give', 'whereupon', 'first', 'these', 'though', 'she', 'ltd', 'everywhere', 'interest', 'indeed', 'onto', 'whatever', 'been', 'thence', 'have', 'noone', 'side', 'whither', 'as', 'had', 'get', 'therein', 'him', 'us', 'found', 'less', 'fifty', 'hers', 'such', 'latter', 'mine', 'call', 'both', 'over', 'third', 'nobody', 'than', 'anywhere', 'will', 'move', 'those', 'seems', 'hasnt', 'do', 'via', 'wherein', 'so', 'put', 'well', 'whoever', 'almost', 'ever', 'after', 'thus', 'still', 'to', 'would', 'made', 'throughout', 'without', 'me', 'since', 'yours', 'something', 'whereafter', 'again', 'system', 'are', 'due', 'latterly', 'couldnt', 'thereby', 'along', 'sixty', 'within', 'per', 'across', 'sometimes', 'four', 'detail', 'behind', 'other', 'many', 'done', 'nor', 'out', 'ours', 'you', 'from', 'before', 'it', 'whose', 'on', 'describe', 'may', 'yourself', 'around', 'everything', 'am', 'together', 'front', 'themselves', 'fill', 'herself', 'much', 'our', 'below', 'an', 'more', 'eight', 'whereas', 'anything', 'please', 'among', 'amount', 'bottom', 'how', 'ten', 'while', 'my', 'whether', 'could', 'there', 'con', 'we', 'thick', 'they', 'down', 'against', 'show', 'often', 'about', 'through', 'who', 'cry', 'for', 'further', 'seeming', 'inc', 'were', 'thereupon', 'her', 'someone', 'why', 'was', 'anyway', 'until', 'least', 'itself', 'already', 'whom', 're', 'hundred', 'because', 'another', 'ourselves', 'their', 'former', 'formerly', 'sometime', 'last', 'becoming', 'find', 'whence', 'somehow', 'is', 'several', 'three', 'all', 'enough', 'where', 'most', 'that', 'amoungst', 'with', 'into', 'same', 'empty', 'become', 'mostly', 'six', 'two', 'cant', 'when', 'now', 'fire', 'thin', 'afterwards', 'full', 'no', 'at', 'your', 'eleven', 'beyond', 'hence', 'this', 'between', 'mill', 'name', 'yourselves', 'towards', 'of', 'if', 'his', 'might', 'or', 'twelve', 'in', 'yet', 'twenty', 'although', 'top', 'five', 'bill', 'part', 'its', 'up', 'own', 'moreover', 'rather', 'has', 'nothing', 'even', 'any', 'beforehand', 'each', 'cannot', 'otherwise', 'then', 'whenever', 'one', 'toward', 'and', 'amongst', 'be', 'becomes', 'under', 'always', 'only', 'un', 'whereby', 'back', 'namely', 'none', 'hereby', 'forty', 'sincere', 'somewhere', 'herein', 'go', 'seem', 'the', 'thru', 'once', 'himself', 'wherever', 'not', 'which', 'ie', 'etc', 'here', 'alone', 'a', 'hereupon', 'perhaps', 'became', 'fifteen', 'keep', 'being', 'either', 'by', 'whole', 'elsewhere', 'beside', 'can', 'every', 'what', 'except', 'see', 'others', 'never', 'should', 'during', 'else', 'therefore', 'serious', 'besides', 'also', 'off', 'nine', 'but', 'few', 'he', 'however', 'anyhow', 'nevertheless', 'de', 'hereafter', 'them', 'thereafter', 'some', 'must', 'nowhere', 'seemed', 'take', 'co', 'neither', 'above', 'eg', 'next'})

# %% [markdown]
# * Check the most popular words only for some years

# %%
vectorizer = CountVectorizer(stop_words='english')
docs       = vectorizer.fit_transform(corpus[200:500])
features   = vectorizer.get_feature_names()

visualizer = FreqDistVisualizer(features=features, n=75,  size= (520, 860))
visualizer.fit(docs)
visualizer.show()

# %% [markdown]
# ### Lemmatizing

# %%
spacyen = spacy.load('en_core_web_sm')

# %%
corpus_all_lower = []

for each in corpus_all:
    each = each.lower().split()
    corpus_all_lower.extend(each)
    
corpus_all_lower
# Out:
# ['facebook',
#  's',
#  'utilisation',
#  'of',
#  'machine',
#  'learning',
#  'and',
#  'artificial',
#  'intelligence',
#  'ai',
#  'can',
#  'often',
#  'identify',
#  'profitable',
#  'targets',
#  'more',
#  'quickly',
#  'and',
#  'more',
#  'effectively',
#  'than',
#  'can',
#  'human',
#  'campaign',
#  'managers',
#  'however',
#  'there',
#  'is',
#  'still',
#  'much',
#  'that',
#  'marketers',
#  'may',
#  'do',
#  'to',
#  'ensure',
#  'optimal',
#  'placement',
#  'and',
#  'delivery',
#  'when',
#  'it',
#  'comes',
#  'to',
#  'their',
#  'facebook',
#  'ad',
#  'campaigns',
#  'and',
#  'leveraging',
#  'the',
#  'power',
#  'of',
#  'facebook',
#  's',
#  'machine',
#  'learning',
#  'and',
#  'ai',
#  'capabilities',
#  'this',
#  'article',
#  'discusses',
#  'the',
#  'some',
#  'of',
#  'the',
#  'issues',
#  'that',
#  'marketers',
#  'face',
#  'in',
#  'trying',
#  'to',
#  'fully',
#  'utilise',
#  'facebook',
#  's',
#  'machine',
#  'learning',
#  'capabilities',
#  'and',
#  'how',
#  'many',
#  'marketers',
#  'struggle',
#  'to',
#  'create',
#  'campaign',
#  'structures',
#  'that',
#  'allow',
#  'them',
#  'to',
#  'optimise',
#  'and',
#  'scale',
#  'their',
#  'digital',
#  'campaigns',
#  'on',
#  'facebook',
#  'this',
#  'article',
#  'will',
#  'detail',
#  'a',
#  'few',
#  'of',
#  'these',
#  'frameworks',
#  'strategies',
#  'and',
#  'tactics',
#  'the',
#  'article',
#  'does',
#  'not',
#  'advocate',
#  'the',
#  'right',
#  'framework',
#  'to',
#  'use',
#  'but',
#  'rather',
#  'argues',
#  'simply',
#  'that',
#  'having',
#  'a',
#  'framework',
#  'will',
#  'ensure',
#  'better',
#  'results',
#  'and',
#  'support',
#  'learning',
#  'throughout',
#  'the',
#  'campaign',
#  'within',
#  'digital',
#  'marketing',
#  'marketing',
#  'intelligence',
#  'fosters',
#  'two',
#  'major',
#  'developments',
#  'first',
#  'and',
#  'even',
#  'in',
#  'the',
#  'absence',
#  'of',
#  'key',
#  'performance',
#  'indicators',
#  'it',
#  'improves',
#  'marketing',
#  'efficiency',
#  'as',
#  'life',
#  'cycle',
#  'marketing',
#  'automated',
#  'price',
#  'adjustment',
#  'and',
#  'programmatic',
#  'advertising',
#  'based',
#  'on',
#  'artificial',
#  'intelligence',
#  'ai',
#  'all',
#  'support',
#  'the',
#  'vision',
#  'of',
#  'fully',
#  'standardised',
#  'marketing',
#  'automation',
#  'with',
#  'real',
#  'time',
#  'optimised',
#  'customer',
#  'centricity',
#  'secondly',
#  'new',
#  'marketing',
#  'areas',
#  'such',
#  'as',
#  'viral',
#  'marketing',
#  'social',
#  'media',
#  'marketing',
#  'and',
#  'content',
#  'marketing',
#  'emphasise',
#  'the',
#  'increasing',
#  'significance',
#  'of',
#  'creative',
#  'marketing',
#  'looking',
#  'for',
#  'paradigmatic',
#  'principles',
#  'reveals',
#  'that',
#  'performance',
#  'marketing',
#  'is',
#  'shaped',
#  'by',
#  'analytic',
#  'processual',
#  'and',
#  'lean',
#  'thinking',
#  'in',
#  'contrast',
#  'creative',
#  'marketing',
#  'depends',
#  'on',
#  'agile',
#  'outside',
#  'in',
#  'thinking',
#  'as',
#  'a',
#  'key',
#  'element',
#  'in',
#  'the',
#  'debate',
#  'regarding',
#  'marketing',
#  '3',
#  '0',
#  'thus',
#  'digitisation',
#  'seems',
#  'to',
#  'foster',
#  'paradigmatic',
#  'incompatibilities',
#  'within',
#  'marketing',
#  '4',
#  '0',
#  'this',
#  'paper',
#  'argues',
#  'that',
#  'until',
#  'big',
#  'data',
#  'and',
#  'ai',
#  'can',
#  'judge',
#  'creativity',
#  'the',
#  'digitisation',
#  'of',
#  'marketing',
#  'will',
#  'continue',
#  'to',
#  'suffer',
#  'teething',
#  'problems',
#  'symbols',
#  'are',
#  'powerful',
#  'in',
#  'branding',
#  'and',
#  'marketing',
#  'to',
#  'represent',
#  'tourist',
#  'attractions',
#  'by',
#  'bridging',
#  'semiotics',
#  'marketing',
#  'and',
#  'data',
#  'science',
#  'in',
#  'the',
#  'tourism',
#  'context',
#  'this',
#  'study',
#  'uncovers',
#  'the',
#  'destination',
#  'image',
#  'based',
#  'on',
#  'instagram',
#  'photographs',
#  'this',
#  'study',
#  'constructed',
#  'a',
#  'novel',
#  'methodological',
#  'framework',
#  'by',
#  'evaluating',
#  'different',
#  'machine',
#  'learning',
#  'models',
#  'to',
#  'group',
#  'textual',
#  'information',
#  'based',
#  'on',
#  'pictorial',
#  'content',
#  'the',
#  'results',
#  'highlighted',
#  'specific',
#  'destination',
#  'image',
#  'clusters',
#  'such',
#  'as',
#  'the',
#  'wilderness',
#  'and',
#  'spirituality',
#  'of',
#  'alpine',
#  'experiences',
#  'this',
#  'information',
#  'facilitates',
#  'marketers',
#  'understanding',
#  'of',
#  'tourists',
#  'preferences',
#  'and',
#  'movement',
#  'it',
#  'also',
#  'discloses',
#  'blind',
#  'spots',
#  'that',
#  'are',
#  'less',
#  'promoted',
#  'by',
#  'the',
#  'marketers',
#  'click',
#  'through',
#  'rate',
#  'ctr',
#  'prediction',
#  'is',
#  'essential',
#  'for',
#  'targeted',
#  'advertising',
#  'and',
#  'recommendation',
#  'at',
#  'present',
#  'machine',
#  'learning',
#  'models',
#  'are',
#  'widely',
#  'used',
#  'to',
#  'build',
#  'ctr',
#  'estimators',
#  'including',
#  'logistic',
#  'regression',
#  'lr',
#  'factorization',
#  'machine',
#  'fm',
#  'and',
#  'deep',
#  'neural',
#  'network',
#  'dnn',
#  'unfortunately',
#  'these',
#  'models',
#  'adopt',
#  'the',
#  'single',
#  'structure',
#  'that',
#  'only',
#  'considers',
#  'either',
#  'low',
#  'order',
#  'feature',
#  'interactions',
#  'such',
#  'as',
#  'lr',
#  'and',
#  'fm',
#  'or',
#  'high',
#  'order',
#  'feature',
#  'interactions',
#  'such',
#  'as',
#  'dnn',
#  'not',
#  'sufficient',
#  'for',
#  'ctr',
#  'prediction',
#  'therefore',
#  'the',
#  'joint',
#  'learning',
#  'models',
#  'are',
#  'proposed',
#  'such',
#  'as',
#  'wide',
#  'deep',
#  'and',
#  'deepfm',
#  'which',
#  'can',
#  'exploit',
#  'both',
#  'high',
#  'and',
#  'low',
#  'order',
#  'feature',
#  'interactions',
#  'to',
#  'predict',
#  'ctr',
#  'by',
#  'combining',
#  'two',
#  'different',
#  'models',
#  'in',
#  'this',
#  'paper',
#  'we',
#  'first',
#  'analyze',
#  'the',
#  'typical',
#  'ctr',
#  'prediction',
#  'models',
#  'structures',
#  'and',
#  'performance',
#  'and',
#  'then',
#  'summarize',
#  'the',
#  'general',
#  'form',
#  'and',
#  'design',
#  'rules',
#  'of',
#  'ctr',
#  'estimators',
#  'based',
#  'on',
#  'the',
#  'general',
#  'form',
#  'we',
#  'further',
#  'design',
#  'a',
#  'new',
#  'joint',
#  'learning',
#  'model',
#  'that',
#  'combines',
#  'two',
#  'different',
#  'residual',
#  'networks',
#  'to',
#  'explore',
#  'the',
#  'feature',
#  'interactions',
#  'automatically',
#  'compared',
#  'with',
#  'the',
#  'widely',
#  'adopted',
#  'feed',
#  'forward',
#  'neural',
#  'network',
#  'the',
#  'residual',
#  'network',
#  'is',
#  'more',
#  'capable',
#  'of',
#  'exploring',
#  'complex',
#  'feature',
#  'interactions',
#  'at',
#  'different',
#  'layers',
#  'additionally',
#  'we',
#  'introduce',
#  'a',
#  'neural',
#  'attention',
#  'network',
#  'to',
#  'learn',
#  'the',
#  'importance',
#  'of',
#  'each',
#  'second',
#  'order',
#  'interaction',
#  'of',
#  'features',
#  'from',
#  'various',
#  'fields',
#  'finally',
#  'we',
#  'evaluate',
#  'the',
#  'prediction',
#  'performance',
#  'of',
#  'the',
#  'proposed',
#  'model',
#  'based',
#  'on',
#  'two',
#  'real',
#  'world',
#  'datasets',
#  'i',
#  'e',
#  'criteo',
#  'and',
#  'avazu',
#  'in',
#  'terms',
#  'of',
#  'logloss',
#  'and',
#  'auc',
#  'metrics',
#  'the',
#  'extensive',
#  'experimental',
#  'results',
#  'demonstrate',
#  'our',
#  'model',
#  'performs',
#  'the',
#  'best',
#  'compared',
#  'to',
#  'the',
#  'state',
#  'of',
#  'the',
#  'art',
#  'baselines',
#  'recommender',
#  'systems',
#  'are',
#  'used',
#  'in',
#  'e',
#  'commerce',
#  'websites',
#  'to',
#  'make',
#  'product',
#  'recommendations',
#  'or',
#  'deliver',
#  'personalized',
#  'content',
#  'to',
#  'users',
#  'we',
#  'constructed',
#  'a',
#  'beer',
#  'recommendation',
#  'program',
#  'using',
#  'review',
#  'data',
#  'from',
#  'existing',
#  'online',
#  'community',
#  'to',
#  'test',
#  'the',
#  'hypotheses',
#  'this',
#  'research',
#  'aims',
#  'to',
#  'bridge',
#  'the',
#  'gap',
#  'between',
#  'marketing',
#  'and',
#  'computer',
#  'science',
#  'by',
#  'investigating',
#  'the',
#  'moderating',
#  'effects',
#  'of',
#  'consumer',
#  'knowledge',
#  'expertise',
#  'on',
#  'the',
#  'performance',
#  'and',
#  'evaluation',
#  'of',
#  'two',
#  'widely',
#  'used',
#  'recommendation',
#  'systems',
#  'user',
#  'based',
#  'collaborative',
#  'filtering',
#  'and',
#  'content',
#  'based',
#  'the',
#  'results',
#  'show',
#  'that',
#  'expert',
#  'consumers',
#  'prefer',
#  'user',
#  'based',
#  'collaborative',
#  'filtering',
#  'systems',
#  'whereas',
#  'there',
#  'is',
#  'no',
#  'difference',
#  'between',
#  'the',
#  'two',
#  'systems',
#  'among',
#  'novice',
#  'consumers',
#  'theoretical',
#  'and',
#  'managerial',
#  'implications',
#  'are',
#  'discussed',
#  'among',
#  'the',
#  'many',
#  'approaches',
#  'towards',
#  'fuel',
#  'economy',
#  'the',
#  'adoption',
#  'of',
#  'electric',
#  'vehicles',
#  'ev',
#  'may',
#  'have',
#  'the',
#  'greatest',
#  'impact',
#  'however',
#  'existing',
#  'studies',
#  'on',
#  'ev',
#  'adoption',
#  'predict',
#  'very',
#  'different',
#  'market',
#  'evolutions',
#  'which',
#  'causes',
#  'a',
#  'lack',
#  'of',
#  'solid',
#  'ground',
#  'for',
#  'strategic',
#  'decision',
#  'making',
#  'new',
#  'methodological',
#  'tools',
#  'based',
#  'on',
#  'artificial',
#  'intelligence',
#  'might',
#  'offer',
#  'a',
#  'different',
#  'perspective',
#  'this',
#  'paper',
#  'proposes',
#  'supervised',
#  'machine',
#  'learning',
#  'ml',
#  'techniques',
#  'to',
#  'identify',
#  'key',
#  'elements',
#  'in',
#  'ev',
#  'adoption',
#  'comparing',
#  'different',
#  'ml',
#  'methods',
#  'for',
#  'the',
#  'classification',
#  'of',
#  'potential',
#  'ev',
#  'purchasers',
#  'namely',
#  'support',
#  'vector',
#  'machines',
#  'artificial',
#  'neural',
#  'networks',
#  'deep',
#  'neural',
#  'networks',
#  'gradient',
#  'boosting',
#  'models',
#  'distributed',
#  'random',
#  'forests',
#  'and',
#  'extremely',
#  'randomized',
#  'forests',
#  'are',
#  'modeled',
#  'utilizing',
#  'data',
#  'gathered',
#  'on',
#  'users',
#  'inclinations',
#  'towards',
#  'ev',
#  'although',
#  'a',
#  'support',
#  'vector',
#  'machine',
#  'with',
#  'polynomial',
#  'kernel',
#  'slightly',
#  'outperforms',
#  'the',
#  'other',
#  'algorithms',
#  'all',
#  'of',
#  'them',
#  'exhibit',
#  'comparable',
#  'predictability',
#  'implying',
#  'robust',
#  'findings',
#  'further',
#  'analysis',
#  'provides',
#  'evidence',
#  'that',
#  'having',
#  'only',
#  'partial',
#  'information',
#  'e',
#  'g',
#  'only',
#  'socioeconomic',
#  'variables',
#  'has',
#  'a',
#  'significant',
#  'negative',
#  'impact',
#  'on',
#  'model',
#  'performance',
#  'and',
#  'that',
#  'the',
#  'synergy',
#  'across',
#  'several',
#  'types',
#  'of',
#  'variables',
#  'leads',
#  'to',
#  'higher',
#  'accuracy',
#  'finally',
#  'the',
#  'examination',
#  'of',
#  'misclassified',
#  'observations',
#  'reveals',
#  'two',
#  'well',
#  'differentiated',
#  'groups',
#  'unveiling',
#  'the',
#  'importance',
#  'that',
#  'the',
#  'profiling',
#  'of',
#  'potential',
#  'purchaser',
#  'may',
#  'have',
#  'for',
#  'marketing',
#  'campaigns',
#  'as',
#  'well',
#  'as',
#  'for',
#  'public',
#  'agencies',
#  'that',
#  'seek',
#  'to',
#  'promote',
#  'ev',
#  'adoption',
#  'the',
#  'impact',
#  'of',
#  'price',
#  'and',
#  'price',
#  'changes',
#  'should',
#  'not',
#  'be',
#  'ignored',
#  'while',
#  'designing',
#  'algorithms',
#  'for',
#  'predicting',
#  'customer',
#  'choice',
#  'consumer',
#  'preferences',
#  'should',
#  'be',
#  'modeled',
#  'with',
#  'consideration',
#  'of',
#  'price',
#  'effects',
#  'businesses',
#  'need',
#  'to',
#  'consider',
#  'for',
#  'efficient',
#  'prediction',
#  'of',
#  'an',
#  'individual',
#  's',
#  'purchase',
#  'behaviour',
#  'personalized',
#  'recommendation',
#  'systems',
#  'have',
#  'been',
#  'studied',
#  'with',
#  'machine',
#  'learning',
#  'algorithms',
#  'however',
#  'the',
#  'price',
#  'aware',
#  'personalized',
#  'recommendation',
#  'has',
#  'received',
#  'little',
#  'attention',
#  'in',
#  'this',
#  'paper',
#  'we',
#  'attempt',
#  'to',
#  'capture',
#  'insightful',
#  'economic',
#  'results',
#  'considered',
#  'in',
#  'the',
#  'marketing',
#  'and',
#  ...]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
  
corpus_all_lower_lemma =[]    
    
for each1 in corpus_all_lower:
    each1 = lemmatizer.lemmatize(each1)
    corpus_all_lower_lemma.extend(each1)
    
#corpus_all_lower_lemma

# %%
    
len(corpus_all_lower_lemma)
# Out:
# 1365036

# %% [markdown]
# ## Divide corpus into sentences

# %%
corpus[0]
# Out:
# 'Facebook’s utilisation of machine learning and artificial intelligence (AI) can often identify profitable targets more quickly and more effectively than can human campaign managers. However, there is still much that marketers may do to ensure optimal placement and delivery when it comes to their Facebook Ad campaigns and leveraging the power of Facebook’s machine learning and AI capabilities. This article discusses the some of the issues that marketers face in trying to fully utilise Facebook’s machine-learning capabilities and how many marketers struggle to create campaign structures that allow them to optimise and scale their digital campaigns on Facebook. This article will detail a few of these frameworks, strategies and tactics. The article does not advocate the ‘right’ framework to use but rather argues simply that having a framework will ensure better results and support learning throughout the campaign.'

# %%
re.split(r'[a-zA-Z][a-zA-Z][.!?][ ]|[^a-zA-Z][.!?][ ][A-Z]', corpus[0])
# Out:
# ['Facebook’s utilisation of machine learning and artificial intelligence (AI) can often identify profitable targets more quickly and more effectively than can human campaign manage',
#  'However, there is still much that marketers may do to ensure optimal placement and delivery when it comes to their Facebook Ad campaigns and leveraging the power of Facebook’s machine learning and AI capabiliti',
#  'This article discusses the some of the issues that marketers face in trying to fully utilise Facebook’s machine-learning capabilities and how many marketers struggle to create campaign structures that allow them to optimise and scale their digital campaigns on Facebo',
#  'This article will detail a few of these frameworks, strategies and tacti',
#  'The article does not advocate the ‘right’ framework to use but rather argues simply that having a framework will ensure better results and support learning throughout the campaign.']

# %%
len(re.split(r'[a-zA-Z][a-zA-Z][.!?][ ]|[^a-zA-Z][.!?][ ][A-Z]', corpus[0]))
# Out:
# 5

# %%
corpus_sentences = []

for i in range(0,len(corpus)):
    #split the current abstract into sentences
    sentences = re.split(r'[a-zA-Z][a-zA-Z][.!?][ ]|[^a-zA-Z][.!?][ ][A-Z]', corpus[i])
    #nr of sentences in current abstract
    nr_of_sentences = len(sentences)
    corpus_sentences.append(nr_of_sentences)

# %%
df.loc[:,'nr_sentences_abstract']=corpus_sentences
# Out:
# C:\Users\amt\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\amt\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df
# Out:
#                      eid                                doi  \
# 0     2-s2.0-85103933471                               None
# 1     2-s2.0-85103991839                               None
# 3     2-s2.0-85102648080      10.1016/j.tourman.2021.104318
# 4     2-s2.0-85103668790       10.1016/j.neucom.2021.02.036
# 5     2-s2.0-85103407280   10.1016/j.jretconser.2021.102528
# 6     2-s2.0-85104133729     10.1016/j.techfore.2021.120759
# 7     2-s2.0-85104061127   10.1016/j.jretconser.2021.102573
# 8     2-s2.0-85103731784      10.1016/j.jenvman.2021.112509
# 9     2-s2.0-85104445685   10.1016/j.jretconser.2021.102576
# 10    2-s2.0-85101388014       10.1016/j.neucom.2021.01.061
# 11    2-s2.0-85102449056         10.1007/s40171-021-00262-0
# 12    2-s2.0-85099393297      10.1016/j.tourman.2021.104288
# 13    2-s2.0-85102834259          10.1016/j.dss.2021.113536
# 14    2-s2.0-85103948648       10.1016/j.compag.2021.106132
# 15    2-s2.0-85101055208          10.1016/j.chb.2021.106721
# 16    2-s2.0-85100045147     10.1016/j.techfore.2020.120555
# 17    2-s2.0-85101423007          10.1016/j.dss.2021.113497
# 19    2-s2.0-85098569035         10.1007/s00521-020-05548-5
# 20    2-s2.0-85099021701         10.1007/s11205-020-02605-3
# 21    2-s2.0-85066110679          10.1016/j.ins.2019.05.027
# 22    2-s2.0-85104932146       10.1016/j.compag.2021.106085
# 23    2-s2.0-85098729733   10.1016/j.jretconser.2020.102430
# 24    2-s2.0-85099827359           10.1177/0022242920974986
# 25    2-s2.0-85104826729                               None
# 26    2-s2.0-85097041616         10.1016/j.eswa.2020.114287
# 31    2-s2.0-85104592039                               None
# 35    2-s2.0-85104426210        10.17762/turcomat.v12i4.504
# 36    2-s2.0-85104405019       10.17762/turcomat.v12i4.1184
# 37    2-s2.0-85104319179       10.17762/turcomat.v12i6.2375
# 38    2-s2.0-85104482267        10.17762/turcomat.v12i5.899
# ...                  ...                                ...
# 3457   2-s2.0-0023994268                               None
# 3458  2-s2.0-85025514566      10.1016/S0736-5853(88)80007-8
# 3462  2-s2.0-85040898464                               None
# 3464   2-s2.0-0024133980          10.1080/08839518808949906
# 3465   2-s2.0-0023966118       10.1016/0378-7206(88)90050-X
# 3466  2-s2.0-84950045325     10.1080/08853134.1988.10754484
# 3468   2-s2.0-0023578019                               None
# 3470  2-s2.0-34250101539                 10.1007/BF01891273
# 3471  2-s2.0-51249177243                 10.1007/BF02723403
# 3472  2-s2.0-19244385044                               None
# 3473   2-s2.0-0023347264                               None
# 3474   2-s2.0-0023347359                               None
# 3475   2-s2.0-0023314731       10.1016/0168-1699(87)90001-9
# 3478   2-s2.0-0023249713                               None
# 3479  2-s2.0-84912822872     10.1080/08853134.1987.10754451
# 3480  2-s2.0-45949120804       10.1016/0270-0255(87)90005-4
# 3481   2-s2.0-0023330738      10.1016/S0020-7373(87)80078-0
# 3482   2-s2.0-0023295227       10.1016/0378-7206(87)90060-7
# 3484   2-s2.0-0022958315                               None
# 3489   2-s2.0-0022667547                               None
# 3490   2-s2.0-0022955953       10.1016/0167-8493(86)90009-4
# 3491   2-s2.0-0022863812  10.1243/PIME_PROC_1986_200_080_02
# 3494   2-s2.0-0022240697                               None
# 3498   2-s2.0-0021875087                 10.1007/BF00992524
# 3499   2-s2.0-0022026187                               None
# 3500   2-s2.0-0022028267                               None
# 3502   2-s2.0-0022192653       10.1016/0747-5632(85)90022-6
# 3505   2-s2.0-0000133127       10.1016/0361-3682(84)90020-5
# 3507  2-s2.0-84976796492              10.1145/953032.804603
# 3508   2-s2.0-0015413233        10.2190/CQX3-R31D-L15N-6ER0
#
#                        pii pubmed_id  \
# 0                     None      None
# 1                     None      None
# 3        S0261517721000376      None
# 4        S0925231221002824      None
# 5        S0969698921000941      None
# 6        S0040162521001918      None
# 7        S0969698921001399      None
# 8        S0301479721005715      None
# 9        S0969698921001429      None
# 10       S0925231221000898      None
# 11                    None      None
# 12       S0261517721000078      None
# 13       S0167923621000464      None
# 14       S0168169921001502      None
# 15       S0747563221000431      None
# 16       S0040162520313810      None
# 17       S0167923621000075      None
# 19                    None      None
# 20                    None      None
# 21       S0020025519304268      None
# 22       S0168169921001034      None
# 23       S0969698920314375      None
# 24                    None      None
# 25                    None      None
# 26       S0957417420309891      None
# 31                    None      None
# 35                    None      None
# 36                    None      None
# 37                    None      None
# 38                    None      None
# ...                    ...       ...
# 3457                  None      None
# 3458     S0736585388800078      None
# 3462                  None      None
# 3464                  None      None
# 3465      037872068890050X      None
# 3466                  None      None
# 3468                  None      None
# 3470                  None      None
# 3471                  None      None
# 3472                  None      None
# 3473                  None      None
# 3474                  None      None
# 3475      0168169987900019      None
# 3478                  None      None
# 3479                  None      None
# 3480  0270-0255(87)90005-4      None
# 3481     S0020737387800780      None
# 3482  0378-7206(87)90060-7      None
# 3484                  None      None
# 3489                  None      None
# 3490      0167849386900094      None
# 3491                  None      None
# 3494                  None   3852339
# 3498                  None   3839837
# 3499                  None      None
# 3500                  None      None
# 3502  0747-5632(85)90022-6      None
# 3505  0361-3682(84)90020-5      None
# 3507                  None      None
# 3508                  None      None
#
#                                                   title subtype  \
# 0     Why facebook ads keep failing: Lessons learned...      ar
# 1     Digital marketing: Incompatibilities between p...      ar
# 3     A machine learning approach to cluster destina...      ar
# 4     A joint learning model for click-through predi...      ar
# 5     A tale of two recommender systems: The moderat...      ar
# 6     Classification of potential electric vehicle p...      ar
# 7     A neural network based price sensitive recomme...      ar
# 8     A spatially based quantile regression forest m...      ar
# 9     Shopping centers revisited: The interplay betw...      ar
# 10    Distributed reinforcement learning algorithm o...      ar
# 11    Technology and Entrepreneurial Marketing Decis...      ar
# 12    Value proposition operationalization in peer-t...      ar
# 13    Modeling relationships between retail prices a...      ar
# 14    Design, development, and performance evaluatio...      ar
# 15    “In A.I. we trust?” The effects of parasocial ...      ar
# 16              Artificial Intelligence: A Child's Play      ar
# 17    Would you please like my tweet?! An artificial...      ar
# 19    An intelligent optimization method of E-commer...      ar
# 20    Voter Classification Based on Susceptibility t...      ar
# 21    Targeting customers for profit: An ensemble le...      ar
# 22    Predicting body weight in growing pigs from fe...      ar
# 23    Digital humans in fashion: Will consumers inte...      ar
# 24    Portraying Humans as Machines to Promote Healt...      ar
# 25    Performance enhancement of hybrid algorithm fo...      ar
# 26    Multi-objective Grammatical Evolution of Decis...      ar
# 31    Communication strategies for building social a...      ar
# 35    Click prediction for advertisement in websites...      ar
# 36                Artificial intelligence and marketing      ar
# 37    Sentiment analysis of twitter data by using de...      ar
# 38    Design of ai-based gamification platform for e...      ar
# ...                                                 ...     ...
# 3457                 SYSTEM DOES AN EXPERT JOB ON A PC.      ar
# 3458   Applications of artificial intelligence in Japan      ar
# 3462  An intelligent decision support system for int...      ar
# 3464  Innovator: An expert system for new product la...      ar
# 3465  Information and modeling resources for decisio...      ar
# 3466  Microcomputer applications: The perfect travel...      ar
# 3468  FUJITSU ACTIVITIES FOR KNOWLEDGE-BASED SYSTEM:...      ar
# 3470  Is the learner a computer peripheral? - Artifi...      ar
# 3471  Expert systems: The integrative sales manageme...      ar
# 3472     MECHANICAL DESIGNERS ADD CAD TO THEIR TOOLBOX.      ar
# 3473              JUST SCRATCHING THE SURFACE WITH EMS.      ar
# 3474  PARAMEDICL: A COMPUTER-AIDED MEDICAL DIAGNOSIS...      ar
# 3475  Expert system techniques applied to grain mark...      ar
# 3478  COMPUTER INTEGRATED MANUFACTURING SYSTEM STRUC...      ar
# 3479  Artificial intelligence in sales forecasting a...      ar
# 3480  The role of sequential processing models in ma...      ar
# 3481  The use of alternative knowledge-acquisition p...      ar
# 3482  Management support systems for multinational b...      ar
# 3484  KNOWLEDGE-BASED CONSULTANT FOR FINANCIAL MARKE...      ar
# 3489                     UNIX: THE BIRTH OF A STANDARD.      ar
# 3490  Artificial intelligence in manufacturing: Fore...      ar
# 3491       Computer Integration of Advanced Manufacture      ar
# 3494  Decision support systems for the outpatient of...      ar
# 3498  Challenges facing the distribution of an artif...      ar
# 3499  INTELLICORP: THE SELLING OF ARTIFICIAL INTELLI...      ar
# 3500                      AI MARKET PROSPECTS ARE GOOD.      ar
# 3502  Psychological decision support software for th...      ar
# 3505  The role of attention and memory in accounting...      ar
# 3507       Personal computing: An Adventure of the mind      ar
# 3508           CYBERNETICS - THE SCIENCE OF MANAGEMENT?      ar
#
#      subtypeDescription               creator  \
# 0               Article       Huntinghouse J.
# 1               Article               Lies J.
# 3               Article           Arefieva V.
# 4               Article                Liu M.
# 5               Article  Chinchanachokchai S.
# 6               Article                Bas J.
# 7               Article             Chen S.S.
# 8               Article            Córdoba M.
# 9               Article            Pantano E.
# 10              Article                 Wu G.
# 11              Article          Polas M.R.H.
# 12              Article  Ramos-Henríquez J.M.
# 13              Article               Yang X.
# 14              Article             Massah J.
# 15              Article               Youn S.
# 16              Article            Kashyap R.
# 17              Article           Garvey M.D.
# 19              Article                Cui F.
# 20              Article            Demir M.Ö.
# 21              Article           Lessmann S.
# 22              Article                 He Y.
# 23              Article            Silva E.S.
# 24              Article          Weihrauch A.
# 25              Article              Desai R.
# 26              Article          Pereira P.J.
# 31              Article            Charest F.
# 35              Article              Ramya D.
# 36              Article            Anoop M.R.
# 37              Article           Dabade M.S.
# 38              Article              Nam H.W.
# ...                 ...                   ...
# 3457            Article      Welsh Whitney L.
# 3458            Article              Honda N.
# 3462            Article           Klingman D.
# 3464            Article                Ram S.
# 3465            Article               Iyer R.
# 3466            Article            Collins R.
# 3468            Article              Kanda T.
# 3470            Article             Hilton J.
# 3471            Article          Steinberg M.
# 3472            Article                  Anon
# 3473            Article                  Anon
# 3474            Article            Cutcher M.
# 3475            Article             Thieme R.
# 3478            Article                Ren S.
# 3479            Article            Collins R.
# 3480            Article           Gensch D.H.
# 3481            Article           Mitchell A.
# 3482            Article               Iyer R.
# 3484            Article            Kastner J.
# 3489            Article          Von Alten J.
# 3490            Article           Knasel T.M.
# 3491            Article           Crookall J.
# 3494            Article              Evans S.
# 3498            Article              Evans S.
# 3499            Article             Linden E.
# 3500            Article            Friscia A.
# 3502            Article             Eyde L.D.
# 3505            Article           Birnberg J.
# 3507            Article               Rine D.
# 3508            Article            Charles D.
#
#                                      afid  \
# 0           126017626;126017476;126017461
# 1                               126017869
# 3                       60021931;60009709
# 4                       60159715;60005465
# 5             60032143;60012521;125957352
# 6                       60078684;60006222
# 7     60024666;60024260;60007616;60002027
# 8             60004518;60000658;126000340
# 9              60171669;60020650;60020261
# 10                      60073724;60010851
# 11                              109606759
# 12                               60003044
# 13             60090931;60016094;60004538
# 14                      60023636;60022927
# 15                      60104765;60000349
# 16             60121755;60113213;60013983
# 17            60122502;60116407;106591216
# 19             60031454;60001298;60000174
# 20    60210179;60198720;60010104;60004300
# 21             60116071;60107838;60000762
# 22                      60139022;60004923
# 23                               60113405
# 24                                   None
# 25                               60114821
# 26                               60020475
# 31                      60110693;60032619
# 35             60104476;60100984;60080696
# 36                               60106946
# 37           60106996;123416471;123176357
# 38                               60005581
# ...                                   ...
# 3457                            101161076
# 3458                   60018279;113773462
# 3462                                 None
# 3464                             60010065
# 3465                             60004351
# 3466                             60031892
# 3468                                 None
# 3470                             60000112
# 3471                             60014612
# 3472                                 None
# 3473                                 None
# 3474                            100383083
# 3475                    60013959;60009254
# 3478                             60025278
# 3479                             60013402
# 3480                    60123801;60019909
# 3481                             60016849
# 3482                             60003467
# 3484                             60021293
# 3489                            122319006
# 3490                            100370570
# 3491                             60004407
# 3494                             60012028
# 3498                             60012028
# 3499                                 None
# 3500                            100407440
# 3502                            100590404
# 3505                    60015543;60010065
# 3507                             60010100
# 3508                                 None
#
#                                               affilname  ... article_number  \
# 0                   TAB Bank;Fluid Advertising;TAB Bank  ...           None
# 1                     FOM University of Applied Science  ...           None
# 3     Johannes Kepler University Linz;Fachhochschule...  ...         104318
# 4     Xiaomi, Inc.;University of Electronic Science ...  ...           None
# 5     University of Akron;Thammasat University;Datag...  ...         102528
# 6     A. James Clark School of Engineering;Newcastle...  ...         120759
# 7     National Central University Taiwan;Universität...  ...         102573
# 8     Consejo Nacional de Investigaciones Científica...  ...         112509
# 9     Middlesex University Business School;Universit...  ...         102576
# 10    Yancheng Institute of Technology;Hohai University  ...           None
# 11         Limkokwing University of Creative Technology  ...           None
# 12                             Universidad de la Laguna  ...         104288
# 13    Henry B. Tippie College of Business;Dongbei Un...  ...         113536
# 14    Gorgan University of Agricultural Sciences and...  ...         106132
# 15     Northwestern University in Qatar;Emerson College  ...         106721
# 16    Singapore University of Social Sciences;S P Ja...  ...         120555
# 17    Frank G. Zarb School of Business;D'Amore-McKim...  ...         113497
# 19    Xi'an University of Architecture and Technolog...  ...           None
# 20    WSB University in Gdansk;Alanya Alaaddin Keyku...  ...           None
# 21    Audencia;Lille Économie Management ( LEM );Hum...  ...           None
# 22           Smithfield Foods, Inc.;NC State University  ...         106085
# 23                            London College of Fashion  ...         102430
# 24                                                 None  ...           None
# 25                            Terna Engineering College  ...           None
# 26                                Universidade do Minho  ...         114287
# 31              Université Côte d'Azur;Université Laval  ...           None
# 35    Vel Tech Rangarajan Dr.Sagunthala R&amp;D Inst...  ...           None
# 36            Symbiosis Institute of Management Studies  ...           None
# 37    Sinhgad College of Engineering, Pune;Padmabhoo...  ...           None
# 38                           Dongduk Women's University  ...           None
# ...                                                 ...  ...            ...
# 3457                            Gold Hill Computers Inc  ...           None
# 3458  Yokohama National University;University of Ele...  ...           None
# 3462                                               None  ...           None
# 3464                          The University of Arizona  ...           None
# 3465                          Universiti Teknologi MARA  ...           None
# 3466                    University of Nevada, Las Vegas  ...           None
# 3468                                               None  ...           None
# 3470                          University of East Anglia  ...           None
# 3471                             University of Hartford  ...           None
# 3472                                               None  ...           None
# 3473                                               None  ...           None
# 3474                                                ICL  ...           None
# 3475            University of Florida;Purdue University  ...           None
# 3478                                Tsinghua University  ...           None
# 3479                            Oregon State University  ...           None
# 3480  College of Business Administration;University ...  ...           None
# 3481                              University of Toronto  ...           None
# 3482               The University of Texas at Arlington  ...           None
# 3484                    International Business Machines  ...           None
# 3489                               Electronics Products  ...           None
# 3490                                     MK-Ferguson Co  ...           None
# 3491                               Cranfield University  ...           None
# 3494                               Creighton University  ...           None
# 3498                               Creighton University  ...           None
# 3499                                               None  ...           None
# 3500                                      Int Data Corp  ...           None
# 3502                U.S. Office of Personnel Management  ...           None
# 3505  University of Pittsburgh;The University of Ari...  ...           None
# 3507                        Western Illinois University  ...           None
# 3508                                               None  ...           None
#
#       pageRange                                        description  \
# 0       298-307  Facebook’s utilisation of machine learning and...
# 1       376-386  Within digital marketing, marketing intelligen...
# 3          None  Symbols are powerful in branding and marketing...
# 4       206-219  Click-through rate (CTR) prediction is essenti...
# 5          None  Recommender systems are used in e-Commerce web...
# 6          None  Among the many approaches towards fuel economy...
# 7          None  The impact of price and price changes should n...
# 8          None  Rural land valuation plays an important role i...
# 9          None  This paper revisits shopping centers' characte...
# 10      212-222  As a key enabling technology in the emerging n...
# 11       95-112  The prime concern of this study is to explore ...
# 12         None  The purpose of this paper is to operationalize...
# 13         None  Setting the retail price as a part of marketin...
# 14         None  One of the applications of robotic farmer-assi...
# 15         None  Despite the hype surrounding Artificial Intell...
# 16         None  We discuss the objectives of any endeavor in c...
# 17         None  An understudied area in the field of social me...
# 19    4097-4110  In order to improve the marketing effect of e-...
# 20      355-370  The current literature on the campaigns of pol...
# 21      286-301  Marketing messages are most effective if they ...
# 22         None  A timely and accurate estimation of body weigh...
# 23         None  The ongoing COVID-19 pandemic is disrupting th...
# 24      184-203  To fight obesity and educate consumers on how ...
# 25    2703-2711  Telemarketing is an interactive direct marketi...
# 26         None  The worldwide adoption of mobile devices is ra...
# 31        35-50  This article presents some communication strat...
# 35      271-276  Prediction is one of the most powerful and eff...
# 36    1247-1256  Artificial intelligence (AI) has grown in rece...
# 37      962-970  In today’s world, social media is viral and ea...
# 38      286-292  Due to the advancement of advanced technologie...
# ...         ...                                                ...
# 3457       None  An expert system, the Customer Order Relaying ...
# 3458      39-52  This article presents a comprehensive report o...
# 3462       None  This paper defines the basic elements and stru...
# 3464    129-148  Expert systems have become an increasingly imp...
# 3465      67-73  Decision support through information and model...
# 3466      67-70  Having the use of a computer on an extended bu...
# 3468    353-368  Artificial Intelligence (AI) is moving from th...
# 3470    127-136  Interactive Video (IV) is now firmly establish...
# 3471      55-62  Personal computer technology has provided a ma...
# 3472       None  Market forces are driving mechanical engineers...
# 3473      27-28  Looking back on the period 1981 to 1986 we hav...
# 3474    376-384  The paper describes, in general terms, an expe...
# 3475    299-308  Grain marketing problems are often relegated t...
# 3478      87-96  Computer integrated manufacturing system (CIMS...
# 3479      77-80  Sales and marketing professionals utilize stat...
# 3480    869-882  Mathematical models, derived from underlying a...
# 3481    399-411  The knowledge-acquisition procedures used in d...
# 3482      59-64  Domestic and multinational firms face competit...
# 3484      71-79  This article describes an effort to develop a ...
# 3489      49-52  The paper introduces System V Unix system whic...
# 3490    357-362  The use of artificial intelligence in manufact...
# 3491    257-264  An inhibiting misconception in the advancement...
# 3494    445-458  To achieve the economies of scale needed to ma...
# 3498      79-89  The marketing and successful distribution of a...
# 3499  22-23, 25  A profile of a company that pioneered the comm...
# 3500      41-42  Artificial intelligence (AI) has been referred...
# 3502    321-336  Decision Support Systems, when based on psycho...
# 3505    365-382  Behavioral research in accounting has ignored ...
# 3507          8  “A National Educational TV Series at Pre-Colle...
# 3508    331-342  Evolving from principles observed in telecommu...
#
#                                            authkeywords citedby_count  \
# 0     Digital advertising | Digital marketing | Face...             0
# 1     Creativity | Marketing 3.0 | Marketing 4.0 | M...             0
# 3     Destination image | Instagram | Machine learni...             1
# 4     Click-through rate prediction | Joint learning...             0
# 5     Algorithm | Artificial intelligence | Consumer...             0
# 6     Adoption | Cluster analysis | Electric vehicle...             0
# 7     Consumer behaviour | Customer-product interact...             0
# 8     Machine learning | Mass appraisal | Prediction...             0
# 9     Brand image | Consumer behavior | Place attrac...             0
# 10    Multi-agent | Network slicing | Operator compe...             0
# 11    Bangladesh | COVID-19 | Entrepreneurial market...             2
# 12    Classification | Features selection | Machine ...             0
# 13    Consumer reviews | Data-driven | Genetic progr...             0
# 14    Evolutionary algorithms | Machine vision | Sup...             0
# 15    AI Chatbot user experience (UI) and user exper...             0
# 16    68Q32 computational learning theory | 68T05 le...             0
# 17    Bayesian statistics | Business analytics | Mar...             0
# 19    E-commerce | Machine learning | Product market...             1
# 20    Machine learning | Persuasive strategies | Pol...             0
# 21    Business value | Machine learning | Marketing ...             9
# 22    Body weight | Feeding behavior | Machine learn...             0
# 23    Consumer behaviour | Digital humans | E-commer...             0
# 24    (performance) expectation | artificial intelli...             1
# 25    Banking | Deep learning | Financial services |...             0
# 26    Conversion Rate (CVR) prediction | Decision Tr...             0
# 31    Anonymous video analysis (ava) | Artificiel in...             0
# 35    Advertising | Linear Regression | Machine Lear...             0
# 36                                                 None             0
# 37    Deep learning | Fine grain sentiment analysis ...             0
# 38    And Products in data processing) | Application...             0
# ...                                                 ...           ...
# 3457                                               None             4
# 3458                                               None             0
# 3462                                               None             1
# 3464                                               None            12
# 3465  Decision support systems | International inves...             3
# 3466                                               None             5
# 3468                                               None             0
# 3470  choice enablement | computer based training | ...             0
# 3471                                               None            25
# 3472                                               None             0
# 3473                                               None             0
# 3474                                               None             1
# 3475                                               None             5
# 3478                                               None             0
# 3479                                               None             3
# 3480                                               None             0
# 3481                                               None            17
# 3482  Data Support Systems | Decision Support System...             6
# 3484                                               None            14
# 3489                                               None             0
# 3490  Artificial Intelligence | Engineering Workstat...             1
# 3491                                               None             6
# 3494                                               None             0
# 3498                                               None             1
# 3499                                               None             2
# 3500                                               None             0
# 3502                                               None             4
# 3505                                               None            45
# 3507                                               None             0
# 3508                                               None             0
#
#      openaccess fund_acr             fund_no  \
# 0             0     None           undefined
# 1             0     None           undefined
# 3             1     None           undefined
# 4             0     NSFC            61202445
# 5             0     None           undefined
# 6             0     None           undefined
# 7             0     None           undefined
# 8             0     UNDP      PNUD AR/16/005
# 9             0     None           undefined
# 10            0     NSFC             KC17072
# 11            1     None           undefined
# 12            0     None           undefined
# 13            0     NSFC           L17AGL012
# 14            0     None           undefined
# 15            0     None           undefined
# 16            0     None           undefined
# 17            0     None           undefined
# 19            0     NSFC             18JZ037
# 20            0     None           undefined
# 21            0     None           undefined
# 22            1     None           undefined
# 23            0      HCI           undefined
# 24            1     None           undefined
# 25            0     None           undefined
# 26            0      FCT  UID/CEC/00319/2019
# 31            0     None           undefined
# 35            1     None           undefined
# 36            1     None           undefined
# 37            1     None           undefined
# 38            1      DWU           undefined
# ...         ...      ...                 ...
# 3457          0     None           undefined
# 3458          0     None           undefined
# 3462          0     None           undefined
# 3464          0     None           undefined
# 3465          0     None           undefined
# 3466          0     None           undefined
# 3468          0     None           undefined
# 3470          0     None           undefined
# 3471          0     None           undefined
# 3472          0     None           undefined
# 3473          0     None           undefined
# 3474          0     None           undefined
# 3475          0     None           undefined
# 3478          0     None           undefined
# 3479          0     None           undefined
# 3480          1     None           undefined
# 3481          0      MSI           undefined
# 3482          0     None           undefined
# 3484          0     None           undefined
# 3489          0     None           undefined
# 3490          0     None           undefined
# 3491          0     None           undefined
# 3494          0     None           undefined
# 3498          0     None           undefined
# 3499          0     None           undefined
# 3500          0     None           undefined
# 3502          0     None           undefined
# 3505          0     None           undefined
# 3507          0     None           undefined
# 3508          0     None           undefined
#
#                                       fund_sponsor nr_sentences_abstract
# 0                                             None                     5
# 1                                             None                     7
# 3                                             None                     6
# 4     National Natural Science Foundation of China                    10
# 5                                             None                     5
# 6                                             None                     8
# 7                                             None                    13
# 8             United Nations Development Programme                    13
# 9                                             None                     5
# 10    National Natural Science Foundation of China                     9
# 11                                            None                    10
# 12                          Fundación CajaCanarias                     8
# 13    National Natural Science Foundation of China                     7
# 14                                            None                    10
# 15                                            None                     8
# 16                                            None                    10
# 17                                            None                     7
# 19    National Natural Science Foundation of China                     6
# 20                                            None                     8
# 21                                            None                     8
# 22                                            None                    14
# 23                       Huntsman Cancer Institute                     6
# 24                                            None                     7
# 25                                            None                    14
# 26          Fundação para a Ciência e a Tecnologia                     9
# 31                                            None                     3
# 35                                            None                     7
# 36                                            None                    16
# 37                                            None                    14
# 38                      Dongduk Women`s University                     7
# ...                                            ...                   ...
# 3457                                          None                     5
# 3458                                          None                     6
# 3462                                          None                     4
# 3464                                          None                     9
# 3465                                          None                     5
# 3466                                          None                    23
# 3468                                          None                     3
# 3470                                          None                     3
# 3471                                          None                     4
# 3472                                          None                    10
# 3473                                          None                     7
# 3474                                          None                     3
# 3475                                          None                     7
# 3478                                          None                     3
# 3479                                          None                     5
# 3480                                          None                    11
# 3481                   Marketing Science Institute                    10
# 3482                                          None                     7
# 3484                                          None                     5
# 3489                                          None                     2
# 3490                                          None                     3
# 3491                                          None                    10
# 3494                                          None                     6
# 3498                                          None                     4
# 3499                                          None                     3
# 3500                                          None                     3
# 3502                                          None                     6
# 3505                                          None                     3
# 3507                                          None                    10
# 3508                                          None                     4
#
# [1285 rows x 35 columns]

# %%
df.nr_sentences_abstract.describe()
# Out:
# count    1285.000000
# mean        8.365759
# std         3.580852
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        46.000000
# Name: nr_sentences_abstract, dtype: float64

# %%
print(df.nr_sentences_abstract.sum(), "total number of sentences")
print(df.nr_sentences_abstract.median(), "median")
print(df.nr_sentences_abstract.describe())
# Out:
# 10750 total number of sentences
# 8.0 median
# count    1285.000000
# mean        8.365759
# std         3.580852
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        46.000000
# Name: nr_sentences_abstract, dtype: float64

# %%
 print(df.loc[df['nr_sentences_abstract'] == 46]['description'].values)
# Out:
# ['Subject area: PT. Bank Central Asia, Tbk. (BCA), the largest national private bank in Indonesia, won an award for the Best Bank at the Euromoney Awards for Excellence (Asia) 2014. During the same event, in several categories, haloBCA  and BCA employees also won several awards. Previously, a number of awards were received by BCA such as: Best Indonesia Local Private Bank in 2010, Contact Center World Champion in 2012 and 2013, and Best Mega Contact Center in Asia Pacific Region in 2014. BCA is currently facing a problem of an aging population. Since the economy crisis facing the country in 1998, BCA has recruited fewer employees. The company resumed recruiting in 2010. BCA’s human resource (HR) profile in 2013 showed that nearly half of BCA’s permanent employees were aged 45 years or older, 40 per cent of whom have been working for more than 20 years. At the time of their retirement, the Bank faces the potential of losing a significant number of employees from three different generations. BCA has raised its efforts to recruit new talent. However, recruitment is not easy, as BCA wants its new employees to continue maintaining BCA’s heritage, building the Bank to become an Indonesian company that they can be proud of. How have these values, which have been a common belief, a foundation to work passionately and the glue that bonds the Bank’s employees, executives and owners, been communicated outside of the BCA and have been used to attract the future successors of BCA in Indonesia? Study level/applicability: Master Degree in Human Resources Management or MBA Program. Case overview: PT Bank Central Asia Tbk (BCA), which was established on February 1957, is Indonesia’s largest lender by market value and the second largest bank by assets. The bank has experienced a remarkable recovery from the Asian Financial Crisis in the late 1990s when the Indonesian banking system became almost bankrupt. It provides both commercial and personal banking services through its 1,000-plus branches across the country. As the largest national private bank, BCA is a well-known bank in Indonesia. BCA is managing more than 12 million customer accounts, processing hundreds of millions of financial transactions and fulfilling the needs of individual and corporate customers through various products and services. BCA Automatic Teller Machines (ATMs) are located virtually and BCA’s Electronic Data Capture (EDC) machines are available at many merchants both in big cities or small towns across Indonesia’s archipelago. However, for a nation with a population of more than 240 million spread out over 34 provinces, the presence of BCA is still deemed unevenly distributed. In the next 10 years, BCA has no plan yet of expanding outside of Indonesia. BCA put its attention on developing its market in Eastern Indonesia. Funding sources, which usually becomes an issue for expanding companies, are not a source of concern for BCA. BCA is currently facing a problem of an aging population. Since the economy crisis facing the country in 1998, BCA has recruited fewer new employees. The company had recently resumed recruiting in 2010. BCA’s HR profile in 2013 showed that nearly half of BCA’s permanent employees were 45 years of age or older, 40 percent of whom have been working for more than 20 years. At the time of their retirement, the Bank faces the potential of losing a significant number of employees from three different generations. Currently, BCA has raised its efforts to recruit new talent and its future leaders through various programs, such as: BCA Development Program (BDP), one of the most acknowledged management trainee programs in the Indonesian banking industry, provides intensive and rigorous training to selected new recruits to ensure development of BCA key talents and future leaders. HR business partners that actively visit campuses in the eastern region of Indonesia. Socialization programs in state and private universities. Job fairs, Web recruitment, interns ...

# %%
df.loc[df['nr_sentences_abstract'] == 46]['description']
# Out:
# 1922    Subject area: PT. Bank Central Asia, Tbk. (BCA...
# Name: description, dtype: object

# %%
re.split(r'[a-zA-Z][a-zA-Z][.!?][ ]|[^a-zA-Z][.!?][ ][A-Z]', df.loc[1922]["description"])
# Out:
# ['Subject area: ',
#  'Bank Central Asia, T',
#  '(BCA), the largest national private bank in Indonesia, won an award for the Best Bank at the Euromoney Awards for Excellence (Asia) 201',
#  'uring the same event, in several categories, haloBCA  and BCA employees also won several awar',
#  'Previously, a number of awards were received by BCA such as: Best Indonesia Local Private Bank in 2010, Contact Center World Champion in 2012 and 2013, and Best Mega Contact Center in Asia Pacific Region in 201',
#  'CA is currently facing a problem of an aging populati',
#  'Since the economy crisis facing the country in 1998, BCA has recruited fewer employe',
#  'The company resumed recruiting in 201',
#  'CA’s human resource (HR) profile in 2013 showed that nearly half of BCA’s permanent employees were aged 45 years or older, 40 per cent of whom have been working for more than 20 yea',
#  'At the time of their retirement, the Bank faces the potential of losing a significant number of employees from three different generatio',
#  'BCA has raised its efforts to recruit new tale',
#  'However, recruitment is not easy, as BCA wants its new employees to continue maintaining BCA’s heritage, building the Bank to become an Indonesian company that they can be proud ',
#  'How have these values, which have been a common belief, a foundation to work passionately and the glue that bonds the Bank’s employees, executives and owners, been communicated outside of the BCA and have been used to attract the future successors of BCA in Indones',
#  'Study level/applicability: Master Degree in Human Resources Management or MBA Progr',
#  'Case overview: PT Bank Central Asia Tbk (BCA), which was established on February 1957, is Indonesia’s largest lender by market value and the second largest bank by asse',
#  'The bank has experienced a remarkable recovery from the Asian Financial Crisis in the late 1990s when the Indonesian banking system became almost bankru',
#  'It provides both commercial and personal banking services through its 1,000-plus branches across the count',
#  'As the largest national private bank, BCA is a well-known bank in Indones',
#  'BCA is managing more than 12 million customer accounts, processing hundreds of millions of financial transactions and fulfilling the needs of individual and corporate customers through various products and servic',
#  'BCA Automatic Teller Machines (ATMs) are located virtually and BCA’s Electronic Data Capture (EDC) machines are available at many merchants both in big cities or small towns across Indonesia’s archipela',
#  'However, for a nation with a population of more than 240 million spread out over 34 provinces, the presence of BCA is still deemed unevenly distribut',
#  'In the next 10 years, BCA has no plan yet of expanding outside of Indones',
#  'BCA put its attention on developing its market in Eastern Indones',
#  'Funding sources, which usually becomes an issue for expanding companies, are not a source of concern for B',
#  'BCA is currently facing a problem of an aging populati',
#  'Since the economy crisis facing the country in 1998, BCA has recruited fewer new employe',
#  'The company had recently resumed recruiting in 201',
#  'CA’s HR profile in 2013 showed that nearly half of BCA’s permanent employees were 45 years of age or older, 40 percent of whom have been working for more than 20 yea',
#  'At the time of their retirement, the Bank faces the potential of losing a significant number of employees from three different generatio',
#  'Currently, BCA has raised its efforts to recruit new talent and its future leaders through various programs, such as: BCA Development Program (BDP), one of the most acknowledged management trainee programs in the Indonesian banking industry, provides intensive and rigorous training to selected new recruits to ensure development of BCA key talents and future leade',
#  'HR business partners that actively visit campuses in the eastern region of Indones',
#  'Socialization programs in state and private universiti',
#  'Job fairs, Web recruitment, internships and employee referrals, job opportunity advertisements posted at BCA branch offices located near universities and in the leading mass med',
#  'Utilization of recruitment consultant services, especially to find candidates with specific qualificatio',
#  'Utilization of communication media printed (poster, flyer, booklet, banners) and electronical',
#  'Provision of scholarships to high school graduates with excellent academic records but facing financial difficulti',
#  'However, recruitment is not easy for BCA because – like other well-known companies in Indonesia – the Bank only recruits the best people based on the prospective employees’ hard and soft competenci',
#  'BCA’s aim to project a positive perception toward its employees as “a fun workplace with family-oriented atmosphere, and commitment about employees’ development” has yet to strongly resonate in Indonesia’s labor mark',
#  'BCA wants its new employees to continue maintaining BCA’s heritage, building the Bank to become an Indonesian company that they can be proud ',
#  'How have these values, which have been a common belief, a foundation to work passionately and the glue that bonds the Bank’s employees, executives and owners, been communicated outside of BCA and have been used to attract the future successors of BCA in Indones',
#  'How should BCA obtain a large number of qualified talent pools through an effective Employer Branding strate',
#  'Expected learning outcomes: By the end of discussing the case, the learner will be: conceptually: able to explain what is meant by employer branding, internal and external approach and able to explain the relationship of employer branding with business strategy, talent management strategies and HR management functions as a whole; practically: able to identify and analyze BCA Recent Condition – able to explain the BCA brand image in the eyes of public/external/job seekers in Indonesia and internal/current employees of BCA – able to identify strategies that BCA does to recruit potential job seekers – and able to explain the influence of innovative products and services that BCA has currently on BCA employer branding; able to identify BCA goals/needs; able to identify the characteristics, needs and preferences of BCA target group of workers, concerning to the latest issues arise such as: Gen Y and AEC (ASEAN Economic Community); able to evaluate the effectiveness of BCA employer branding strategy and communications and to identify the problems faced by BCA related to employer branding; able to generate ideas related to the improvement of BCA employer branding strategy and programs – what message to be branded (company unique employee value propositions – tangibles and intangibles) – what program to be implemented (internal and external) – and how is the integrated marketing communication strategy (segmenting-targeting-positioning, channels',
#  'upplementary materials: Teaching notes are available for educators on',
#  'Please contact your library to gain login details or email support@emeraldinsight.com to request teaching not',
#  'Subject code: CSS:6: Human Resource Manageme',
#  'TM']

# %%
#We should also extract the keywords maybe

# %%
keywords = df["authkeywords"].tolist()

# %%
keywords[0]
# Out:
# 'Digital advertising | Digital marketing | Facebook | Machine learning | Social media | Video marketing'

# %%
keywords_all = []

for i in range(0,len(keywords)):
    res = re.findall(r'\w+[a-zA-Z][ ][|]', keywords[i])
    keywords_all.extend(res)
    
keywords_all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-281-29e839ce69c3> in <module>
#       2
#       3 for i in range(0,len(keywords)):
# ----> 4     res = re.findall(r'\w+[a-zA-Z][ ][|]', keywords[i])
#       5     keywords_all.extend(res)
#       6
#
# ~\Anaconda3\lib\re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object
